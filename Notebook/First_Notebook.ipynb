# %% [markdown]
# # Bai tap chuong 1 TT_XLA

# %%
from skimage import color,data
coffe_image = data.coffee()
coins_image = data.coins()

coffe_image.shape
coins_image.shape
# Out:
# (303, 384)

# %%
import matplotlib.pyplot as plt
def show_image(image, title='Image', cmap_type='gray'): 
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')  
    plt.show()

from skimage import data,color
rocket=data.rocket()
gray_scaled_rocket=color.rgb2gray(rocket)
show_image(rocket,'Original RGB image')
show_image(gray_scaled_rocket,'Grayscale image')

# %%
from skimage import data
import numpy as np  
flipped_seville = plt.imread('D:/Workspace/Python/Notebook/cam.jpg')
seville_vertical_flip = np.flipud(flipped_seville)

show_image(flipped_seville, 'Original Image')
show_image(seville_vertical_flip, 'Vertically flipped image')

# %%
import numpy as np  
image = plt.imread('D:/Workspace/Python/Notebook/Vinh1.jpg')
show_image(image)
red_channel = image[:,:,0]
plt.hist(red_channel.ravel(),bin=256)
plt.title('Red Histogram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3 show_image(image)
#       4 red_channel = image[:,:,0]
# ----> 5 plt.hist(red_channel.ravel(),bin=256)
#       6 plt.title('Red Histogram')
#       7 plt.show()
#
# File d:\Anaconda\lib\site-packages\matplotlib\pyplot.py:2618, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2612 @_copy_docstring_and_deprecators(Axes.hist)
#    2613 def hist(
#    2614         x, bins=None, range=None, density=False, weights=None,
#    2615         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2616         orientation='vertical', rwidth=None, log=False, color=None,
#    2617         label=None, stacked=False, *, data=None, **kwargs):
# -> 2618     return gca().hist(
# ...

# %%
from skimage import color, filters

image = plt.imread('D:/Workspace/Python/Notebook/Test.jpg')
image_gray = color.rgb2gray(image)
thresh = filters.threshold_otsu(image_gray)
binary = image_gray > thresh
show_image(image, 'Original Image')
show_image(binary, 'Otsu Thresholding')

# %%
from skimage import color, filters

test_image = plt.imread('D:/Workspace/Python/Notebook/Test.jpg')
test_image_gray = color.rgb2gray(test_image)
thresh = filters.threshold_local(test_image_gray)
binary_global = test_image_gray > thresh
show_image(test_image, 'Original Image')
show_image(binary_global, 'Global Thresholding')
print(thresh.shape)
# Out:
# (935, 1080)

# %%
from skimage import color, filters

image7 = plt.imread('D:/Workspace/Python/Notebook/Test.jpg')
image7_gray = color.rgb2gray(image7)

fig, ax = filters.try_all_threshold(image7_gray, verbose = False)

plt.show()

# %%
from skimage import color, filters

image8 = plt.imread('D:/Workspace/Python/Notebook/Test8.jpg')
image8_gray = color.rgb2gray(image8)

thresh = filters.threshold_li(image8_gray)
binary_li = image8_gray > thresh

show_image(binary_li, 'Binarized Image')
